# %% [markdown]
# <a href="https://colab.research.google.com/github/nikithamanikonda/BNFO301_Manikonda_Nikitha/blob/main/BNFO_Week1_Manikonda_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <h1>BNFO301 Week 1: Introductory Material </h1>
#
# Welcome to Google Colab and the first week of classes! In this assignment, you will be tasked with showing knowledge of Github and working through a fun introductory code (creating a rock, paper, scissors game/algorithm)
#
# For the Rock, Paper Scissors Algorithm, create a continuous function that will play rock, papers, scissors with the user until the user requests to stop.
#
# *There is pseudo/broken code that can be completed to run this code, but you are not required to use it. Please be aware of the honor code policy while completing this assignment*
#
#
#
# **Helpful Resources:** <br>
# Introduction to Rock,Paper, Scissors Game: https://en.wikipedia.org/wiki/Rock_paper_scissors
# <br>While Loops in Python: https://www.geeksforgeeks.org/python-while-loop/#:~:text=Python%20While%20Loop%20is%20used,the%20category%20of%20indefinite%20iteration.
# <br>Random Import Documentation:https://docs.python.org/3/library/random.html
#
#
# <br>**This assignment is broken down as such: 2 points for attendance, 3 points for proper setup of github and settings, 1 point for submitting github username to canvas,  4 point completed algorithm**
#
# Meme for the week:<br>
# ![memes.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### Part 0- Getting Started with GoogleColab
# *Note: Heavy credit is given to the "Welcome to Colaboratory" Notebook created by the Google Colab Research Team from which this introductory code is built on*
#
# A Google Colab Notebook is not a static web page, but an interactive environment where you can write and exectute code. <br>
# It has both **text cells** and **code cells**. This text is written in a text cell. Colab notebooks allow you to combine very rich texts using markdown, images HTML, LaTeX, etc. You will not need to learn how to write in markdown for this course, but you have have to interact with the text box. <br>
#
# For fun, double click this box to edit the text and fill out the following sentence for fun: "I feel --blank-- today.

# %% [markdown]
# Below is an example, of a **code cell** with a short Python script that computes a value, stores it in a variable, and prints the result: Try running this code by clicking the play button by hovering over the [ ] or using the keyboard shortcut "Command/Cut+Enter". Also modify the code to a function that calculates "seconds_in_a_day" and rerun the code to see if it works.

# %%
seconds_in_a_hour = 24 * 60
seconds_in_a_hour

# %% [markdown]
# Variables that you define in one cell can later be used in other cells:

# %%
seconds_in_a_week = 7 * seconds_in_a_day
seconds_in_a_week

# %% [markdown]
# ![Screen Shot 2024-01-21 at 7.29.34 PM.png](data:image/png;base64,...)### Part 1- Checking Github Setup
# Please insert a screenshot of your github settings and contributions below. Use the insert image button above, and confirm that your image is inserted by looking at the right side of the screen. <br>

# %% [markdown]
# ### Part 2- Rock, Paper,Scissors Algorithm
# Below is the code space.

# %%
# Imports
import random

# %% [markdown]
# Firstly, let us write the base program. An algorithm that creates the basic algorithm: taking one input of "rock", "paper", or "scissors" and outputs a statement telling the player if they won or lost.

# %%
### Create a list of play options
choices = ["rock", "paper", "scissors"]

### Create a random computer action
computer = random.choice(choices)

### Write a player variable that takes the users input
player = input("Enter your choice: rock, paper, or scissors")

### Set up all of the logical combinations using an if,elif, else statement
# (must take into account false submissions and ties).
# The output should print a statement. Here is is an example:
# If player plays Rock and Computer randomly choses paper, the outcome is
# "You lose! Computer covers paper"

if player == computer:
        return "Tie!"
    elif (
        (player == "rock" and computer == "scissors") or
        (player == "paper" and computer == "rock") or
        (player == "scissors" and computer == "paper")
    ):
        return "You win!"
    else:
        return "You lose!"

# %% [markdown]
# Now, let us put the program written above into a *while* loop. Make sure you create a mechanism to break out of the loop. You may copy and paste your program from above into this section.

# %%
import random
while True:
    choices = ["rock", "paper", "scissors"]
    player = input("Enter your choice rock, paper, or scissors or type 'end' to end the game: ")

    if player == 'end':
        print("Game over.")
        break

    computer = random.choice(choices)

    print(f"You chose: {player}")
    print(f"Computer chose: {computer}")

    if player == computer:
        print("Tie!")
    elif (
        (player == "rock" and computer == "scissors") or
        (player == "paper" and computer == "rock") or
        (player == "scissors" and computer == "paper")
    ):
        print("You win!")
    else:
        print("You lose!")
# Out:
# Enter your choice rock, paper, or scissors or type 'end' to end the game: rock
# You chose: rock
# Computer chose: rock
# Tie!
# Enter your choice rock, paper, or scissors or type 'end' to end the game: paper
# You chose: paper
# Computer chose: paper
# Tie!
# Enter your choice rock, paper, or scissors or type 'end' to end the game: rock
# You chose: rock
# Computer chose: rock
# Tie!
# Enter your choice rock, paper, or scissors or type 'end' to end the game: rock
# You chose: rock
# Computer chose: paper
# You lose!
# Enter your choice rock, paper, or scissors or type 'end' to end the game: end
# Game over.
